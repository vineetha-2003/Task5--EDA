# %% [markdown]
# Imporing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Load the Dataset

# %%
df = pd.read_csv('/content/Titanic-Dataset.csv')

# %% [markdown]
# Data description

# %%
print(df.shape)
print(df.info())
print(df.describe())
print(df.isnull().sum())
# Out:
# (891, 12)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# None
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# ...

# %% [markdown]
# Univariate Analysis

# %% [markdown]
# # Age Distribution

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['Age'].dropna(), bins=30, kde=True)
plt.title('Age Distribution')
plt.show()

# %% [markdown]
# #Survival Count

# %%
sns.countplot(data=df, x='Survived')
plt.title('Survival Count')
plt.show()

# %% [markdown]
# #Passenger Class Distribution

# %%
sns.countplot(data=df, x='Pclass')
plt.title('Passenger Class Distribution')
plt.show()

# %% [markdown]
# Bivariate Analysis

# %% [markdown]
# #Survival vs Gender

# %%
sns.countplot(data=df, x='Sex', hue='Survived')
plt.title('Survival by Gender')
plt.show()

# %% [markdown]
# # Survival vs Passenger Class

# %%
sns.countplot(data=df, x='Pclass', hue='Survived')
plt.title('Survival by Passenger Class')
plt.show()

# %% [markdown]
# # Age vs Fare

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(x='Age', y='Fare', data=df)
plt.title('Age vs Fare')
plt.show()

# %% [markdown]
# Multivariate Analysis

# %% [markdown]
# # Pair Plot

# %%
sns.pairplot(df[['Survived', 'Pclass', 'Age', 'Fare']])
plt.show()

# %% [markdown]
# # Correlation Heatmap

# %%
plt.figure(figsize=(10,6))
numeric_df = df.select_dtypes(include=np.number)
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# Missing Values

# %%
print(df.isnull().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# # Key Observations
# - Younger passengers had slightly higher survival rates.
# - Females had higher survival rates than males.
# - 1st class passengers had a better chance of survival.
# - Fare and Passenger Class are somewhat correlated.
# - Missing values exist in Age, Cabin, and Embarked.
# """)
#
# #Final Summary
#
#
# The dataset shows clear patterns in survival based on gender and class.
# First Class and female passengers had higher survival chances.
# There are missing values in 'Age' and 'Cabin' that could be handled for modeling.
# EDA helped uncover relationships between Age, Fare, and Survival.
